# %%
import os
import pandas as pd

# Configuración de rutas (Subiendo dos niveles a la raíz)
BRONZE_INTERNAS_DIR = os.path.join("..", "..", "data", "bronze", "internas")

# Tu único archivo maestro de DSpace
file_dspace = os.path.join(BRONZE_INTERNAS_DIR, "DSpace_raw.xlsx") 

print("⏳ Cargando pestañas del archivo maestro de DSpace...")

# Cargamos cada hoja de forma independiente especificando su nombre exacto
df_tesis = pd.read_excel(file_dspace, sheet_name="tesis", dtype=str)
df_articulos = pd.read_excel(file_dspace, sheet_name="art_docentes", dtype=str)
df_publicaciones= pd.read_excel(file_dspace, sheet_name="publicaciones", dtype=str)

print(f"✅ Hojas cargadas con éxito:")
print(f"   - Tesis: {df_tesis.shape[0]} registros crudos.")
print(f"   - Artículos: {df_articulos.shape[0]} registros crudos.")
print(f"   - Publicaciones: {df_publicaciones.shape[0]} registros crudos.")
# Out:
# ⏳ Cargando pestañas del archivo maestro de DSpace...
# ✅ Hojas cargadas con éxito:
#    - Tesis: 31550 registros crudos.
#    - Artículos: 2131 registros crudos.
#    - Proyectos: 909 registros crudos.
